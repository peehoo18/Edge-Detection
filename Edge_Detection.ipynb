# %% [markdown]
# # Import Dependencies

# %%
import cv2
import os
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Load Image

# %%
img = cv2.imread(r"C:\Peehoo\Computer Vision\Data\Images\bike.jpg")

# %%
img
# Out:
# array([[[212, 200, 200],
#         [213, 201, 201],
#         [213, 201, 201],
#         ...,
#         [151, 164, 162],
#         [158, 171, 169],
#         [158, 171, 169]],
#
#        [[212, 200, 200],
#         [212, 200, 200],
#         [213, 201, 201],
#         ...,
#         [150, 163, 161],
#         [155, 168, 166],
#         [155, 168, 166]],
#
#        [[211, 199, 199],
#         [212, 200, 200],
#         [213, 201, 201],
#         ...,
#         [148, 162, 158],
#         [152, 166, 162],
#         [152, 166, 162]],
#
#        ...,
#
#        [[ 58,  59,  63],
#         [ 57,  58,  62],
#         [ 98,  99, 103],
#         ...,
#         [ 51,  50,  60],
#         [ 77,  76,  86],
#         [ 86,  84,  96]],
#
#        [[ 78,  79,  83],
#         [ 68,  69,  73],
#         [ 85,  86,  90],
#         ...,
#         [ 77,  77,  83],
#         [ 71,  70,  80],
#         [ 73,  71,  83]],
#
#        [[ 71,  72,  76],
#         [ 67,  68,  72],
#         [ 68,  69,  73],
# ...

# %%
plt.imshow(img)

# %%
cv2.imshow('Frame View', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Edge Detection

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur =cv2.GaussianBlur(gray,(5,5),0)
canny = cv2.Canny(blur,threshold1=180, threshold2=200)
plt.figure()
plt.imshow(canny,cmap='gray')

# %%
#resized= cv2.resize(canny,(int(img.shape[1]/2), int(img.shape[0]/2)))
cv2.imshow('Frame View', canny)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Save Edges Image

# %%
cv2.imwrite(r"C:\Peehoo\Computer Vision\Data\Output\edges.jpg",canny)
# Out:
# True
